# %% [markdown]
# # BPMN Model Comparison

# %%
import sys, os
_root = os.path.abspath("..")
_me = os.path.abspath("../model_evaluation")
if _root not in sys.path:
    sys.path.insert(0, _root)
if _me not in sys.path:
    sys.path.insert(0, _me)

from model_evaluation.rendering.comparison_widget import create_comparison_widget
create_comparison_widget(example_dir="../examples")
